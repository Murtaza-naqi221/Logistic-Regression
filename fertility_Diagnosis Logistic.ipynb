# %%
from numpy import mean
from numpy import std
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
df = pd.read_excel('fertility_Diagnosis.xlsx')
df.head(10)
# Out:
#    Season in which the analysis was performed  Age at the time of analysis  \
# 0                                       -0.33                         0.69
# 1                                       -0.33                         0.94
# 2                                       -0.33                         0.50
# 3                                       -0.33                         0.75
# 4                                       -0.33                         0.67
# 5                                       -0.33                         0.67
# 6                                       -0.33                         0.67
# 7                                       -0.33                         1.00
# 8                                        1.00                         0.64
# 9                                        1.00                         0.61
#
#    Childish diseases  Accident or serious trauma  Surgical intervention  \
# 0                  0                           1                      1
# 1                  1                           0                      1
# 2                  1                           0                      0
# 3                  0                           1                      1
# 4                  1                           1                      0
# 5                  1                           0                      1
# 6                  0                           0                      0
# 7                  1                           1                      1
# 8                  0                           0                      1
# 9                  1                           0                      0
#
#    High fevers in the last yea  Frequency of alcohol consumption  \
# 0                            0                               0.8
# 1                            0                               0.8
# 2                            0                               1.0
# 3                            0                               1.0
# 4                            0                               0.8
# 5                            0                               0.8
# 6                           -1                               0.8
# 7                            0                               0.6
# 8                            0                               0.8
# 9                            0                               1.0
#
#    Smoking habit  Number of hours spent sitting per day Diagnosis
# 0              0                                   0.88         N
# 1              1                                   0.31         O
# 2             -1                                   0.50         N
# 3             -1                                   0.38         N
# 4             -1                                   0.50         O
# 5              0                                   0.50         N
# 6             -1                                   0.44         N
# 7             -1                                   0.38         N
# 8             -1                                   0.25         N
# 9             -1                                   0.25         N

# %%
len(df)
# Out:
# 100

# %%
X = df.drop('Diagnosis',axis=1)
y = df['Diagnosis']

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
y == label_encoder.fit_transform(y)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Diagnosis, Length: 100, dtype: bool

# %%
y
# Out:
# 0     N
# 1     O
# 2     N
# 3     N
# 4     O
#      ..
# 95    N
# 96    N
# 97    N
# 98    N
# 99    N
# Name: Diagnosis, Length: 100, dtype: object

# %%
X, y = make_classification(n_samples=100, n_features=7, n_informative=2, n_redundant=1, random_state=1)
# prepare the cross-validation procedure
cv = KFold(n_splits=10, random_state=1, shuffle=True)
# create model
model = LogisticRegression( dual=False, tol=0.01, C=1.0)
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.970 (0.046)
